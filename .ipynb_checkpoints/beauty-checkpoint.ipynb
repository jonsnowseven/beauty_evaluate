# %%
#Imported libs
import numpy as np
import time
import math
import matplotlib.pyplot as plt
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.models import model_from_json
from keras.optimizers import Adam
from tqdm import tqdm
import cv2
import pandas as pd
import os
import random

#from hyperas import optim
#from hyperas.distributions import choice, uniform
#from hyperopt import Trials, STATUS_OK, tpe

# %%
def get_labels(file):
    with open(file,'r') as f:
        lines = f.readlines()
        return np.array([line.strip().split() for line in lines])
    
def index_process(flo):
    below = math.floor(flo)
    top = math.ceil(flo)
    
    result = np.zeros(5)
    result[below-1] = top-round(flo)
    result[top-1] = round(flo)-below
    
    return result

#loading of images and labels
#Cross validation was made by the dataset provider
PATH = 'Beau/train_test_files/split60/'
train_labels = get_labels(PATH+'train.txt')
test_labels = get_labels(PATH+'test.txt')

PATH2 = 'Beau/Images/'
X_pre_train = [cv2.imread(PATH2+file,0) for file in tqdm(train_labels[:,0])]
X_train = np.array([cv2.resize(img,(160,160),interpolation=cv2.INTER_AREA) for img in X_pre_train])

X_pre_test = [cv2.imread(PATH2+file,0) for file in tqdm(test_labels[:,0])]
X_test = np.array([cv2.resize(img,(160,160),interpolation=cv2.INTER_AREA) for img in X_pre_test])

y_train = np.array([float(flo) for flo in train_labels[:,1]])
y_test = np.array([float(flo) for flo in test_labels[:,1]])
# Out:
# 100%|██████████| 3300/3300 [00:21<00:00, 156.05it/s]
# 100%|██████████| 2200/2200 [00:06<00:00, 342.93it/s]

# %%
total = np.concatenate([y_train,y_test])

# %%
q = sum(np.floor(total)==0)
b = sum(np.floor(total)==1)
a = sum(np.floor(total)==2)
s = sum(np.floor(total)==3)
e = sum(np.floor(total)==4)
r = sum(np.floor(total)>=5)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['0','1', '2', '3', '4', '5']
students = [q,b,a,s,e,r]
ax.bar(langs,students)
plt.title('Distribution of floored indexes')
plt.xlabel('Index of beauty (increasing)')
plt.show()

# %%
X_show = [cv2.imread(PATH2+file) for file in tqdm(train_labels[:10,0])]
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 181.79it/s]

# %%
plt.imshow(X_show[0])
plt.title('The index of attractiveness: {}'.format(str(y_train[0])))
plt.show()

# %%
plt.imshow(X_show[4])
plt.title('The index of attractiveness: {}'.format(str(y_train[4])))
plt.show()

# %%
plt.imshow(X_show[7])
plt.title('The index of attractiveness: {}'.format(str(y_train[7])))
plt.show()

# %%
plt.imshow(X_show[8])
plt.title('The index of attractiveness: {}'.format(str(y_train[8])))
plt.show()

# %%
plt.imshow(X_show[9])
plt.title('The index of attractiveness: {}'.format(str(y_train[9])))
plt.show()

# %%
X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],X_train.shape[2],1))
X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],X_test.shape[2],1))
X_train.shape,y_train.shape
# Out:
# ((3300, 160, 160, 1), (3300,))

# %%
def data():
    def get_labels(file):
        with open(file,'r') as f:
            lines = f.readlines()
            return np.array([line.strip().split() for line in lines])
    
    def index_process(flo):
        below = math.floor(flo)
        top = math.ceil(flo)

        result = np.zeros(5)
        result[below-1] = top-round(flo)
        result[top-1] = round(flo)-below

        return result

    #loading of images and labels
    #Cross validation was made by the dataset provider
    PATH = 'Beau/train_test_files/split60/'
    train_labels = get_labels(PATH+'train.txt')
    test_labels = get_labels(PATH+'test.txt')

    PATH2 = 'Beau/Images/'
    X_pre_train = [cv2.imread(PATH2+file,0) for file in tqdm(train_labels[:,0])]
    X_train = np.array([cv2.resize(img,(160,160),interpolation=cv2.INTER_AREA) for img in X_pre_train])

    X_pre_test = [cv2.imread(PATH2+file,0) for file in tqdm(test_labels[:,0])]
    X_test = np.array([cv2.resize(img,(160,160),interpolation=cv2.INTER_AREA) for img in X_pre_test])

    #y_train = np.array([index_process(float(flo)) for flo in train_labels[:,1]])
    #y_test = np.array([index_process(float(flo)) for flo in test_labels[:,1]])
    
    y_train = np.array([float(flo) for flo in train_labels[:,1]])
    y_test = np.array([float(flo) for flo in test_labels[:,1]])
    
    X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],X_train.shape[2],1))
    X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],X_test.shape[2],1))
    
    return X_train,X_test,y_train,y_test

# %%
class Beau:
    def __init__(self):

        self.model = Sequential()

        #1st 2dConvolutional Layer
        self.model.add(Conv2D(64, (3, 3), padding='same', input_shape=(160, 160, 1)))
        self.model.add(Activation('relu'))

        #1st 2dMaxPool Layer
        self.model.add(MaxPooling2D(pool_size=(2, 2)))
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.25))

        #2nd 2dConvolutional Layer
        self.model.add(Conv2D(64, (3, 3), padding='same'))
        self.model.add(Activation('relu'))

        #2nd 2dMaxPool Layer
        self.model.add(MaxPooling2D(pool_size=(2, 2)))  
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.5))

        #3rd 2dConvolutional Layer
        self.model.add(Conv2D(128, (5, 5), padding='same'))
        self.model.add(Activation('relu'))

        #3rd 2dMaxPool Layer
        self.model.add(MaxPooling2D(pool_size=(2, 2)))  
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.5))
        
        #4th 2dConvolutional Layer
        self.model.add(Conv2D(128, (5, 5), padding='same'))
        self.model.add(Activation('relu'))

        #3rd 2dMaxPool Layer
        self.model.add(MaxPooling2D(pool_size=(2, 2)))  
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.25))
        
        #5th 2dConvolutional Layer
        self.model.add(Conv2D(256, (3, 3), padding='same'))
        self.model.add(Activation('relu'))
        self.model.add(BatchNormalization())

        #3rd 2dMaxPool Layer
        self.model.add(MaxPooling2D(pool_size=(2, 2)))  
        self.model.add(BatchNormalization())
        self.model.add(Dropout(0.25))
        
        #6th 2dConvolutional Layer
        self.model.add(Conv2D(512, (5, 5), padding='same'))
        self.model.add(Activation('relu'))
        self.model.add(BatchNormalization())

        self.model.add(Flatten())

        #1st FC Layer
        self.model.add(Dense(256))
        self.model.add(BatchNormalization())
        self.model.add(Activation('relu'))
        self.model.add(Dropout(0.25))
        
        #2nd FC Layer
        self.model.add(Dense(512))
        self.model.add(BatchNormalization())
        self.model.add(Activation('relu'))
        self.model.add(Dropout(0.25))

        # Output layer
        self.model.add(Dense(1))
        self.model.add(Activation('relu'))

        self.model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
        self.model.summary()

# %%
model = Beau().model
history = model.fit(X_train, y_train,
            batch_size=128,
            epochs=100,
            verbose=1,
            validation_data=(X_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 160, 160, 64)      640
# _________________________________________________________________
# activation_1 (Activation)    (None, 160, 160, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 80, 80, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 80, 80, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 80, 80, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 80, 80, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 80, 80, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 40, 40, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 40, 40, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 40, 40, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 40, 40, 128)       204928
# _________________________________________________________________
# activation_3 (Activation)    (None, 40, 40, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 20, 20, 128)       512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 128)       409728
# _________________________________________________________________
# activation_4 (Activation)    (None, 20, 20, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 512)         3277312
# _________________________________________________________________
# activation_6 (Activation)    (None, 5, 5, 512)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_9 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 7,642,561
# Trainable params: 7,638,209
# Non-trainable params: 4,352
# _________________________________________________________________
# Train on 3300 samples, validate on 2200 samples
# Epoch 1/100
# 3300/3300 [==============================] - 157s 47ms/step - loss: 1.7367 - mean_squared_error: 1.7367 - val_loss: 9.4244 - val_mean_squared_error: 9.4244
# Epoch 2/100
# 3300/3300 [==============================] - 239s 72ms/step - loss: 0.8315 - mean_squared_error: 0.8315 - val_loss: 9.4244 - val_mean_squared_error: 9.4244
# Epoch 3/100
# 3300/3300 [==============================] - 228s 69ms/step - loss: 0.7211 - mean_squared_error: 0.7211 - val_loss: 6.3206 - val_mean_squared_error: 6.3206
# Epoch 4/100
# 3300/3300 [==============================] - 232s 70ms/step - loss: 0.7742 - mean_squared_error: 0.7742 - val_loss: 4.0432 - val_mean_squared_error: 4.0432
# Epoch 5/100
# 3300/3300 [==============================] - 236s 71ms/step - loss: 0.6198 - mean_squared_error: 0.6198 - val_loss: 0.9565 - val_mean_squared_error: 0.9565
# Epoch 6/100
# 3300/3300 [==============================] - 236s 72ms/step - loss: 0.5669 - mean_squared_error: 0.5669 - val_loss: 1.2302 - val_mean_squared_error: 1.2302
# Epoch 7/100
# 3300/3300 [==============================] - 237s 72ms/step - loss: 0.7499 - mean_squared_error: 0.7499 - val_loss: 0.9030 - val_mean_squared_error: 0.9030
# Epoch 8/100
# 3300/3300 [==============================] - 233s 71ms/step - loss: 0.6228 - mean_squared_error: 0.6228 - val_loss: 0.7024 - val_mean_squared_error: 0.7024
# Epoch 9/100
# 3300/3300 [==============================] - 233s 71ms/step - loss: 0.5360 - mean_squared_error: 0.5360 - val_loss: 0.4283 - val_mean_squared_error: 0.4283
# Epoch 10/100
# 3300/3300 [==============================] - 232s 70ms/step - loss: 0.5218 - mean_squared_error: 0.5218 - val_loss: 0.2909 - val_mean_squared_error: 0.2909
# Epoch 11/100
# 3300/3300 [==============================] - 234s 71ms/step - loss: 0.4525 - mean_squared_error: 0.4525 - val_loss: 0.2415 - val_mean_squared_error: 0.2415
# Epoch 12/100
# 3300/3300 [==============================] - 236s 72ms/step - loss: 0.4676 - mean_squared_error: 0.4676 - val_loss: 0.2582 - val_mean_squared_error: 0.2582
# Epoch 13/100
# 3300/3300 [==============================] - 237s 72ms/step - loss: 0.4693 - mean_squared_error: 0.4693 - val_loss: 0.3317 - val_mean_squared_error: 0.3317
# Epoch 14/100
# 3300/3300 [==============================] - 234s 71ms/step - loss: 0.4233 - mean_squared_error: 0.4233 - val_loss: 0.2418 - val_mean_squared_error: 0.2418
# Epoch 15/100
# 3300/3300 [==============================] - 235s 71ms/step - loss: 0.3729 - mean_squared_error: 0.3729 - val_loss: 0.2315 - val_mean_squared_error: 0.2315
# Epoch 16/100
# 3300/3300 [==============================] - 234s 71ms/step - loss: 0.3756 - mean_squared_error: 0.3756 - val_loss: 0.2835 - val_mean_squared_error: 0.2835
# Epoch 17/100
# 3300/3300 [==============================] - 233s 71ms/step - loss: 0.3996 - mean_squared_error: 0.3996 - val_loss: 0.2460 - val_mean_squared_error: 0.2460
# Epoch 18/100
# 3300/3300 [==============================] - 236s 71ms/step - loss: 0.4025 - mean_squared_error: 0.4025 - val_loss: 0.2382 - val_mean_squared_error: 0.2382
# Epoch 19/100
# 2560/3300 [======================>.......] - ETA: 44s - loss: 0.3957 - mean_squared_error: 0.3957

# %%
import pickle
file = open('history.pickle','rb')
data = pickle.load(file)
file.close()

val_loss,train_loss = data['val_loss'],data['loss']

plt.figure(figsize=(10,6))
plt.plot(np.arange(0,len(val_loss)),val_loss,label='validation')
plt.plot(np.arange(0,len(val_loss)),train_loss,label='train')
plt.xlabel('Number of epochs')
plt.ylabel('Mean Squared Error value')
plt.title('MSE as a function of epoch')
plt.legend()
plt.show()

# %%
model = Beau().model
model.load_weights("beau.h5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 160, 160, 64)      640
# _________________________________________________________________
# activation_19 (Activation)   (None, 160, 160, 64)      0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 80, 80, 64)        0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 80, 80, 64)        256
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 80, 80, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 80, 80, 64)        36928
# _________________________________________________________________
# activation_20 (Activation)   (None, 80, 80, 64)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 40, 40, 64)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 40, 40, 64)        256
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 40, 40, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 40, 40, 128)       204928
# _________________________________________________________________
# activation_21 (Activation)   (None, 40, 40, 128)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 20, 20, 128)       0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 20, 20, 128)       512
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 20, 20, 128)       409728
# _________________________________________________________________
# activation_22 (Activation)   (None, 20, 20, 128)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 10, 10, 256)       295168
# _________________________________________________________________
# activation_23 (Activation)   (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 5, 5, 512)         3277312
# _________________________________________________________________
# activation_24 (Activation)   (None, 5, 5, 512)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_25 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_26 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_27 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 7,642,561
# Trainable params: 7,638,209
# Non-trainable params: 4,352
# _________________________________________________________________

# %%
for i in range(len(model.layers)):
    if 'conv' in model.layers[i].name: print(i)
# Out:
# 0
# 5
# 10
# 15
# 20
# 26

# %%
filters, biases = model.layers[26].get_weights()
print(filters.shape)
# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
# plot first few filters
n_filters, ix = 6, 1
plt.figure(figsize=(10,6))
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    print(f[2,1,0])
    # plot each channel separately
    for j in range(3):
        # specify subplot and turn of axis
        ax = plt.subplot(n_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        plt.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
plt.show()
# Out:
# (5, 5, 256, 512)
# 0.28168705
# 0.33428645
# 0.43273273
# 0.37182865
# 0.4751721
# 0.45204616

# %%
np.array(feature_maps).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-2275a0fca9c9> in <module>()
# ----> 1 np.array(feature_maps).shape
#
# ValueError: could not broadcast input array from shape (40,40,64) into shape (1)

# %%
ixs = [10,15, 20]
outputs = [model.layers[i].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
# load the image with the required shape
img = cv2.cvtColor(X_show[9], cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(160,160),interpolation=cv2.INTER_AREA)
img = img.reshape((1,160,160,1))
# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot the output from each block
square = 8
for fmap in feature_maps:
    plt.figure(figsize=(16,10))
    # plot all 64 maps in an 8x8 squares
    ix = 1
    for _ in range(square):
        for _ in range(square):
            # specify subplot and turn of axis
            ax = plt.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            plt.imshow(fmap[0, :, :, ix-1], cmap='gray')
            ix += 1
    # show the figure
    print('\n-----------------------------------------------------------------\n')
    plt.show()
# Out:
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# -----------------------------------------------------------------

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
